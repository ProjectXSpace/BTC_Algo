# %%
from basic_ml.ml_preprocessing import get_features_and_target

# %%
df = get_features_and_target("BTC/USDT")
# Out:
#                      BTC:USDT_sma_9  ...  BTC:USDT_target
# BTC:USDT_timestamp                   ...
# 2017-08-25 11:00:00     4320.886667  ...         0.094865
# 2017-08-25 12:00:00     4320.553333  ...         0.112145
# 2017-08-25 13:00:00     4320.753333  ...         0.107843
# 2017-08-25 14:00:00     4323.415556  ...         0.097749
# 2017-08-25 15:00:00     4333.597778  ...         0.093181
# ...                             ...  ...              ...
# 2023-11-03 07:00:00    34584.507778  ...         0.057305
# 2023-11-03 08:00:00    34527.450000  ...         0.060655
# 2023-11-03 09:00:00    34499.522222  ...         0.066968
# 2023-11-03 10:00:00    34464.524444  ...         0.072074
# 2023-11-03 11:00:00    34417.281111  ...         0.083460
#
# [51161 rows x 64 columns]
